# %% [markdown]
# ## Write your name and make your cover as creative as you want.
#
# ### If a step is a question, answer the question after you solve it! -> print("This is the answer")

# %%
import pandas as pd

# %% [markdown]
# Import all the files

# %%
visits = pd.read_csv('visits.csv',
                     parse_dates=[1])

cart = pd.read_csv('cart.csv',
                   parse_dates=[1])     

checkout = pd.read_csv('checkout.csv',
                       parse_dates=[1])

purchase = pd.read_csv('purchase.csv',
                       parse_dates=[1])

# %% [markdown]
# Step 1: Inspect the DataFrames using `print` and `head`

# %% [markdown]
# Step 2: Left merging visits and cart

# %%
visits_car = #Left merge -> visits.me.....

# %% [markdown]
# Step 3: How long is `visits_cart`?

# %% [markdown]
# Step 4: How many timestamps are null for `cart_time`?

# %%
null_cart_time = # Empty cart time

# %% [markdown]
# Step 5: What percentage only visited?

# %%
visited_not_cart = # use the null carts and the total

# %% [markdown]
# Step 6: What percentage placed a t-shirt in their cart but did not checkout?

# %%
cart_checkout = # left merge cart and checkout

print(" x% of shoppers placed a t-shirt in their cart but did not checkout.")

# %% [markdown]
# Step 7: Merge it all together

# %%
all_data = # left merge and left merge...

# %% [markdown]
# Step 8: % of users who got to checkout but did not purchase

# %% [markdown]
# Step 9: check each part of the funnel, let's print all 3 of them again

# %%
print("{} percent of users who visited the page did not add a t-shirt to their cart".format(round(SOME_ANSWER*100, 2)))
print("{} percent of users who added a t-shirt to their cart did not checkout".format(round(SOME_ANSWER*100, 2)))
print("{} percent of users who made it to checkout  did not purchase a shirt".format(round( SOME_ANSWER*100, 2)

# %% [markdown]
# *The weakest part of the funnel is clearly getting a person who visited the site to add a tshirt to their cart. Once they've added a t-shirt to their cart it is fairly likely they end up purchasing it. A suggestion could be to make the add-to-cart button more prominent on the front page.*
#
#
# Step 10: adding new column

# %%
all_data['time_to_purchase'] = all_data.purchase_time - all_data.visit_time

# %% [markdown]
# Step 11: examine the results

# %% [markdown]
# Step 12: what is the average time to purchase?
